# %%
pip install SpeechRecognition
# Out:
# ...
#
# ...

# %%
pip install selenium
# Out:
# ...
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/dc/72/96b5afa16908f9abc7c24b70adfd3a46c9740eb728ddfeab28379e38eaf9/selenium-4.16.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/3e/14/746bb2b403af4be680ca0ae240d62473c4ec3b836024c2e85f27856d7991/trio-0.23.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for outcome from https://files.pythonhosted.org/packages/55/8b/5ab7257531a5d830fc8000c476e63c935488d74609b50f9384a643ec0a62/outcome-1.3.0.post0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import time
import speech_recognition as sr
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

def send_email(driver, to_email, subject, message):
    # Navigate to Gmail
    driver.get("https://mail.google.com")
    
    # Log in (you need to replace these with your actual credentials)
    email_input = driver.find_element("name", "identifier")
    email_input.send_keys("kbhargavi1503@gmail.com")
    email_input.send_keys(Keys.RETURN)
    time.sleep(2)  # Add a delay to wait for the page to load
    
    password_input = driver.find_element("name", "password")
    password_input.send_keys("Bhargavi@1503")
    password_input.send_keys(Keys.RETURN)
    time.sleep(2)
    
    # Compose and send email
    compose_button = driver.find_element("text", "Compose")
    compose_button.click()
    
    to_input = driver.find_element("name", "to")
    to_input.send_keys('1ds21ai009@gmail.com')
    
    subject_input = driver.find_element("name", "subjectbox")
    subject_input.send_keys()
    
    message_input = driver.find_element("css selector", "div[role='textbox']")
    message_input.send_keys(message)
    
    send_button = driver.find_element("text", "Send")
    send_button.click()
    
    time.sleep(2)

def voice_command():
    # Use the speech recognition library to capture voice commands
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Say something:")
        audio = recognizer.listen(source)
        try:
            command = recognizer.recognize_google(audio).lower()
            return command
        except sr.UnknownValueError:
            print("Sorry, could not understand the audio.")
            return None

if __name__ == "__main__":
    # Initialize the webdriver (you need to specify the path to your webdriver)
    driver = webdriver.Chrome(executable_path="path/to/chromedriver")
    
    # Example voice command scenario
    command = voice_command()
    if command == "send email":
        send_email(driver, "recipient@gmail.com", "Test Subject", "This is a test message")
    
    # Close the browser window
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 54
#      50             return None
#      52 if __name__ == "__main__":
#      53     # Initialize the webdriver (you need to specify the path to your webdriver)
# ---> 54     driver = webdriver.Chrome(executable_path="path/to/chromedriver")
#      56     # Example voice command scenario
#      57     command = voice_command()
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'executable_path'

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

def open_browser():
    choice = input("Enter your choice (6: New Message): ")
    if choice == '6':6
        email = "phanindra33690@gmail.com"
        password = "jduftbbfubqwspiw"
        open_gmail(email, password)
    else:
        print("Invalid choice!")

def open_gmail(email, password):
    try:
        options = webdriver.ChromeOptions()
        options.add_argument('--start-maximized')  # Maximize window on start
        driver = webdriver.Chrome(options=options)

        driver.get('https://mail.google.com')

        # Wait for the Gmail page to load
        time.sleep(5)

        # Enter email address
        email_field = driver.find_element(By.XPATH, '//input[@type="email"]')
        email_field.send_keys(email)
        email_field.send_keys(Keys.RETURN)

        time.sleep(2)  # Wait for password field to load

        # Enter password
        pass_field = driver.find_element(By.XPATH, '//input[@type="password"]')
        pass_field.send_keys(password)
        pass_field.send_keys(Keys.RETURN)

        time.sleep(5)  # Wait for Gmail to load after login

        # Click the Compose button
        compose_button = driver.find_element(By.XPATH, '//div[text()="Compose"]')
        compose_button.click()

        time.sleep(2)  # Wait for the compose window to open

        # Enter recipient, subject, and message
        recipient_field = driver.find_element(By.NAME, 'to')
        recipient_field.send_keys('1ds21ai008@dsce.edu.in')

        subject_field = driver.find_element(By.NAME, 'subjectbox')
        subject_field.send_keys('testing only')

        message_field = driver.find_element(By.CSS_SELECTOR, 'div[aria-label="Message Body"]')
        message_field.send_keys('Hello There! I am hearing to the music What if I didn\'t know by fly by midnight.')

        # Send the email
        send_button = driver.find_element(By.XPATH, '//div[contains(text(),"Send")]')
        send_button.click()

        print("Email sent successfully!")

        # Close the browser after sending the email
        driver.quit()
    except Exception as e:
        print(f"Error composing and sending email: {e}")
        driver.quit()

open_browser()
# Out:
# Enter your choice (6: New Message):  6
# Error composing and sending email: Message: element not interactable
#   (Session info: chrome=120.0.6099.109)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF625492142+3514994]
# 	(No symbol) [0x00007FF6250B0CE2]
# 	(No symbol) [0x00007FF624F574C3]
# 	(No symbol) [0x00007FF624F9B6D7]
# 	(No symbol) [0x00007FF624F9A03E]
# 	(No symbol) [0x00007FF624FC5FEA]
# 	(No symbol) [0x00007FF624F963B6]
# 	(No symbol) [0x00007FF624FC6490]
# 	(No symbol) [0x00007FF624FE28F6]
# 	(No symbol) [0x00007FF624FC5D93]
# 	(No symbol) [0x00007FF624F94BDC]
# 	(No symbol) [0x00007FF624F95C64]
# 	GetHandleVerifier [0x00007FF6254BE16B+3695259]
# 	GetHandleVerifier [0x00007FF625516737+4057191]
# 	GetHandleVerifier [0x00007FF62550E4E3+4023827]
# 	GetHandleVerifier [0x00007FF6251E04F9+689705]
# 	(No symbol) [0x00007FF6250BC048]
# 	(No symbol) [0x00007FF6250B8044]
# 	(No symbol) [0x00007FF6250B81C9]
# 	(No symbol) [0x00007FF6250A88C4]
# ...
